# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Mayank\Downloads\Practice Datasets-20240314T143849Z-001\Practice Datasets\Titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Capping the values

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import seaborn as sns

# %%
sns.boxplot(y = 'Age', data = df)
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# iqr = 75% - 25%
#
# upper_bound = q3+1.5*(iqr)
# lower_bound = q1-1.5*(iqr)

# %%
import numpy as np

# %%
# so we will cap the data at around 0 to 60 

df['New_age'] = np.where(df['Age']<0, 0, (np.where(df['Age']>60, 60, df['Age'])))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_age
# 0      0         A/5 21171   7.2500   NaN        S     22.0
# 1      0          PC 17599  71.2833   C85        C     38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     26.0
# 3      0            113803  53.1000  C123        S     35.0
# ...

# %%
sns.boxplot(y = 'New_age', data = df)
# Out:
# <Axes: ylabel='New_age'>

# %% [markdown]
# #### Clip
#
#     Syntax:
#
#         df['Age'].clip(lower = lower_limit, upper = upper_limit)

# %%
df['new_age'] = df['Age'].clip(lower = 0, upper = 60)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_age  new_age
# 0      0         A/5 21171   7.2500   NaN        S     22.0     22.0
# 1      0          PC 17599  71.2833   C85        C     38.0     38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     26.0     26.0
# ...

# %% [markdown]
# ### Sorting the dataframe on the basis of the column
#
#     Syntax:
#
#         df.sort_values(by = 'column_name')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_age  new_age
# 0      0         A/5 21171   7.2500   NaN        S     22.0     22.0
# 1      0          PC 17599  71.2833   C85        C     38.0     38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     26.0     26.0
# ...

# %%
df.sort_values(by = 'Fare', ignore_index = True)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 0            272         1       3        Tornquist, Mr. William Henry
# 1            598         0       3                 Johnson, Mr. Alfred
# 2            303         0       3     Johnson, Mr. William Cahoone Jr
# 3            634         0       1       Parr, Mr. William Henry Marsh
# 4            278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 886          439         0       1                   Fortune, Mr. Mark
# 887          342         1       1      Fortune, Miss. Alice Elizabeth
# 888          738         1       1              Lesurer, Mr. Gustave J
# 889          259         1       1                    Ward, Miss. Anna
# 890          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...

# %% [markdown]
# ### Sorting on multiple columns

# %%
df = pd.read_csv(r"C:\Users\Mayank\Downloads\Practice Datasets-20240314T143849Z-001\Practice Datasets\Titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sort_values(by = ['Fare', 'Age'], ignore_index = True)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 0            303         0       3     Johnson, Mr. William Cahoone Jr
# 1            272         1       3        Tornquist, Mr. William Henry
# 2            180         0       3                 Leonard, Mr. Lionel
# 3            823         0       1     Reuchlin, Jonkheer. John George
# 4            807         0       1              Andrews, Mr. Thomas Jr
# ..           ...       ...     ...                                 ...
# 886          342         1       1      Fortune, Miss. Alice Elizabeth
# 887          439         0       1                   Fortune, Mr. Mark
# 888          259         1       1                    Ward, Miss. Anna
# 889          738         1       1              Lesurer, Mr. Gustave J
# 890          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values(by = ['Age', 'Fare'], ignore_index = True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            804         1       3
# 1            756         1       2
# 2            470         1       3
# 3            645         1       3
# 4            832         1       2
# ..           ...       ...     ...
# 886          307         1       1
# 887          335         1       1
# 888           32         1       1
# 889          528         0       1
# 890          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                      Thomas, Master. Assad Alexander    male  0.42      0
# 1                            Hamalainen, Master. Viljo    male  0.67      1
# 2                        Baclini, Miss. Helene Barbara  female  0.75      2
# 3                               Baclini, Miss. Eugenie  female  0.75      2
# 4                      Richards, Master. George Sibley    male  0.83      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values(by = ['Age', 'Fare'], ignore_index = True, ascending = False)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0            631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 1            852         0       3                   Svensson, Mr. Johan
# 2            494         0       1               Artagaveytia, Mr. Ramon
# 3             97         0       1             Goldschmidt, Mr. George B
# 4            117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 886          482         0       2      Frost, Mr. Anthony Wood "Archie"
# 887          634         0       1         Parr, Mr. William Henry Marsh
# 888          675         0       2            Watson, Mr. Ennis Hastings
# 889          733         0       2                  Knight, Mr. Robert J
# 890          816         0       1                      Fry, Mr. Richard
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ### Splitting the dataframe into Numerical and object data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
num_data = df.select_dtypes('number')

# %%
num_data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
num_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Age          714 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
# dtypes: float64(2), int64(5)
# memory usage: 48.9 KB

# %%
obj_data = df.select_dtypes('object')

# %%
obj_data.head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
obj_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      891 non-null    object
#  1   Sex       891 non-null    object
#  2   Ticket    891 non-null    object
#  3   Cabin     204 non-null    object
#  4   Embarked  889 non-null    object
# dtypes: object(5)
# memory usage: 34.9+ KB

# %% [markdown]
# ### Iterating over the dataset

# %%
for i in df:
    print(i)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
for i in df:
    print(i)
    print('****************************************')
    print(df[i])
    print('------------------------------------')
# Out:
# PassengerId
# ****************************************
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64
# ------------------------------------
# Survived
# ****************************************
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# ------------------------------------
# Pclass
# ****************************************
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64
# ------------------------------------
# Name
# ****************************************
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# ...

# %% [markdown]
# ### items()
#
# - It return a generator object
# - Each element inside the generator object is a tuple
# - Each tuple will have two values in it, the first value is the column name and the second value is the series)

# %%
for i in df.items():
    print(i)
    print('---------------------------------------------------')
# Out:
# ('PassengerId', 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64)
# ---------------------------------------------------
# ('Survived', 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64)
# ---------------------------------------------------
# ('Pclass', 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64)
# ---------------------------------------------------
# ('Name', 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %% [markdown]
# ### iterrows()
#
# - It also generates a generator object
# - Each element inside the generator object is a tuple
# - Each tuple is going to have two values, the first value is the row index and the second value is the series contains the element from that particular row
# - The column name are the index of the series

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
for i in df.iterrows():
    print(i)
# Out:
# (0, PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object)
# (1, PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# ...

# %% [markdown]
# ### itertuples ()
#
# - It also returns the genertaor object
# - Each element inside the generator object is a pandas object
# - Each pandas object contains the column = value mapping

# %%
for i in df.itertuples():
    print(i)
# Out:
# Pandas(Index=0, PassengerId=1, Survived=0, Pclass=3, Name='Braund, Mr. Owen Harris', Sex='male', Age=22.0, SibSp=1, Parch=0, Ticket='A/5 21171', Fare=7.25, Cabin=nan, Embarked='S')
# Pandas(Index=1, PassengerId=2, Survived=1, Pclass=1, Name='Cumings, Mrs. John Bradley (Florence Briggs Thayer)', Sex='female', Age=38.0, SibSp=1, Parch=0, Ticket='PC 17599', Fare=71.2833, Cabin='C85', Embarked='C')
# Pandas(Index=2, PassengerId=3, Survived=1, Pclass=3, Name='Heikkinen, Miss. Laina', Sex='female', Age=26.0, SibSp=0, Parch=0, Ticket='STON/O2. 3101282', Fare=7.925, Cabin=nan, Embarked='S')
# Pandas(Index=3, PassengerId=4, Survived=1, Pclass=1, Name='Futrelle, Mrs. Jacques Heath (Lily May Peel)', Sex='female', Age=35.0, SibSp=1, Parch=0, Ticket='113803', Fare=53.1, Cabin='C123', Embarked='S')
# Pandas(Index=4, PassengerId=5, Survived=0, Pclass=3, Name='Allen, Mr. William Henry', Sex='male', Age=35.0, SibSp=0, Parch=0, Ticket='373450', Fare=8.05, Cabin=nan, Embarked='S')
# ...

# %% [markdown]
# ### Export a dataframe

# %%
emp = {'name': ['Mayank', 'Rishabh', 'Geetika', 'Deepak', 'Priya'],
       'ID' : [101,102, 103, 104, 105],
       'city':['Bengaluru', 'Noida', 'Ambala', 'Chandigarh', 'Surat']}

# %%
df = pd.DataFrame(emp)

# %%
df
# Out:
#       name   ID        city
# 0   Mayank  101   Bengaluru
# 1  Rishabh  102       Noida
# 2  Geetika  103      Ambala
# 3   Deepak  104  Chandigarh
# 4    Priya  105       Surat

# %%
df.to_csv('March_employee.csv', index = False)

# %%
Matplo
